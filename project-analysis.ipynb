# %%
import numpy as np
import pandas as pd
import plotly.express as px

# %%
latlong = pd.read_csv('E:\DataScienceCampus_ineuron\Projects\DataVisualization-plotly\district wise centroids.csv')
latlong
# Out:
#                    State           District   Latitude  Longitude
# 0    Andaman and Nicobar    Andaman Islands  12.382571  92.822911
# 1    Andaman and Nicobar    Nicobar Islands   7.835291  93.511601
# 2         Andhra Pradesh           Adilabad  19.284514  78.813212
# 3         Andhra Pradesh          Anantapur  14.312066  77.460158
# 4         Andhra Pradesh           Chittoor  13.331093  78.927639
# ..                   ...                ...        ...        ...
# 589          West Bengal  North 24 Parganas  22.062388  88.877940
# 590          West Bengal           Puruliya  23.254192  86.396853
# 591          West Bengal  South 24 Parganas  21.854428  88.445370
# 592          West Bengal     Uttar Dinajpur  26.044619  88.235952
# 593          West Bengal     West Midnapore  22.354897  87.231014
#
# [594 rows x 4 columns]

# %%
latlong.shape
# Out:
# (594, 4)

# %%
latlong.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 594 entries, 0 to 593
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   State      594 non-null    object
#  1   District   594 non-null    object
#  2   Latitude   594 non-null    float64
#  3   Longitude  594 non-null    float64
# dtypes: float64(2), object(2)
# memory usage: 18.7+ KB

# %%
census=pd.read_csv("E:\DataScienceCampus_ineuron\Projects\DataVisualization-plotly\india-districts-census-2011.csv")

# %%
census = census[['District code','District name','Population','Male','Female','Literate','Households_with_Internet','Male_Literate','Female_Literate',
'Hindus','Muslims','Christians','Sikhs','Buddhists','Jains','Others_Religions','Religion_Not_Stated',
'Housholds_with_Electric_Lighting','LPG_or_PNG_Households','Rural_Households','Urban_Households',

'Below_Primary_Education','Primary_Education','Middle_Education','Secondary_Education','Higher_Education','Graduate_Education','Other_Education' ,'Total_Education','Age_Group_0_29'	,'Age_Group_30_49'	,'Age_Group_50'	,'Age not stated','Having_latrine_facility_within_the_premises_Total_Households',
'Household_size_1_person_Households',	'Household_size_2_persons_Households',	'Household_size_3_persons_Households',		'Household_size_4_persons_Households',	'Household_size_5_persons_Households', 'Household_size_6_8_persons_Households',	'Household_size_9_persons_and_above_Households'	
]]

# %%
# census

# %%
census.shape
# Out:
# (640, 41)

# %%
final_df = latlong.merge(census, left_on='District', right_on='District name').drop(columns='District name')

# %%
final_df
# Out:
#               State        District   Latitude  Longitude  District code  \
# 0    Andhra Pradesh        Adilabad  19.284514  78.813212            532
# 1    Andhra Pradesh       Anantapur  14.312066  77.460158            553
# 2    Andhra Pradesh        Chittoor  13.331093  78.927639            554
# 3    Andhra Pradesh   East Godavari  16.782718  82.243207            545
# 4    Andhra Pradesh          Guntur  15.884926  80.586576            548
# ..              ...             ...        ...        ...            ...
# 512     West Bengal          Maldah  25.080268  88.171917            332
# 513     West Bengal     Murshidabad  24.259507  88.168169            333
# 514     West Bengal           Nadia  23.564110  88.582930            336
# 515     West Bengal        Puruliya  23.254192  86.396853            340
# 516     West Bengal  Uttar Dinajpur  26.044619  88.235952            330
#
#      Population     Male   Female  Literate  Households_with_Internet  ...  \
# ...

# %%
#we are calculating female sex ratio
final_df['sex_ratio'] = round((final_df['Female']/final_df['Male'])*1000).astype('int')

# %%
final_df.to_csv('India.csv', index=False)

# %%
final_df['literacy_rate'] = round((final_df['Literate']/final_df['Population'])*100).astype('int')

# %%
final_df
# Out:
#               State        District   Latitude  Longitude  District code  \
# 0    Andhra Pradesh        Adilabad  19.284514  78.813212            532
# 1    Andhra Pradesh       Anantapur  14.312066  77.460158            553
# 2    Andhra Pradesh        Chittoor  13.331093  78.927639            554
# 3    Andhra Pradesh   East Godavari  16.782718  82.243207            545
# 4    Andhra Pradesh          Guntur  15.884926  80.586576            548
# ..              ...             ...        ...        ...            ...
# 512     West Bengal          Maldah  25.080268  88.171917            332
# 513     West Bengal     Murshidabad  24.259507  88.168169            333
# 514     West Bengal           Nadia  23.564110  88.582930            336
# 515     West Bengal        Puruliya  23.254192  86.396853            340
# 516     West Bengal  Uttar Dinajpur  26.044619  88.235952            330
#
#      Population     Male   Female  Literate  Households_with_Internet  ...  \
# ...

# %%
final_df.columns
# Out:
# Index(['State', 'District', 'Latitude', 'Longitude', 'District code',
#        'Population', 'Male', 'Female', 'Literate', 'Households_with_Internet',
#        'Male_Literate', 'Female_Literate', 'Hindus', 'Muslims', 'Christians',
#        'Sikhs', 'Buddhists', 'Jains', 'Others_Religions',
#        'Religion_Not_Stated', 'Housholds_with_Electric_Lighting',
#        'LPG_or_PNG_Households', 'Rural_Households', 'Urban_Households',
#        'Below_Primary_Education', 'Primary_Education', 'Middle_Education',
#        'Secondary_Education', 'Higher_Education', 'Graduate_Education',
#        'Other_Education', 'Total_Education', 'Age_Group_0_29',
#        'Age_Group_30_49', 'Age_Group_50', 'Age not stated',
#        'Having_latrine_facility_within_the_premises_Total_Households',
#        'Household_size_1_person_Households',
#        'Household_size_2_persons_Households',
#        'Household_size_3_persons_Households',
#        'Household_size_4_persons_Households',
# ...
